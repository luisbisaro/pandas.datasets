# %% [markdown]
# <a href="https://colab.research.google.com/github/luisbisaro/pandas.datasets/blob/main/TPFINAL_Luis_Bisaro_Comision_6_grupo_10_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TP FINAL

# %% [markdown]
# **Ejercicio 1**\
# Buscar un dataset (Que no sea los trabajados en clases)
#
# **Ejercicio 2**\
# Realizar una introduccion al dataset de que se trata,definir sus variables (Diccionario de datos)
#
# **Ejercicio 3**\
# Identificar el tipo de variable,decide justificando su respuesta.
#
# **Ejercicio 4**\
# Detectar Valores Ausente  y Valores Atipicos .Decidir si eliminarlos y el por que de la eleccion.
#
# **Ejercicio 5**\
# Realizar un analisis univariado y en base a esos graficos,sacar conclusiones.
#
# **Ejercicio 6**\
# Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# **Ejercicio 7**\
# Sobre el Dataset Elegido  explique si se puede reducir las dimensiones  y que representa esas  nuevas variables.

# %% [markdown]
# ---
# # Introducción
# ---

# %% [markdown]
# ---
# ## Caracteristicas del dataset
# ---
# Generalmente, la clasificación estelar se basa en la temperatura y luminosidad, aunque ciertamente las estrellas presentan diversas características que las distinguen individualmente, como tamaño, ciclo de vida, magnitud, etc. Esta primera clasificación se conoce con el nombre de clasificación espectral de Harvard y recibe su nombre por haber sido desarrollada en la universidad de Harvard a finales del siglo XIX. Esta clasificación es la más habitual que utilizan los astrónomos. Se encarga de dividir a todas las estrellas según la temperatura que tienen y la luminosidad que otorgan. Se engloban 7 tipos de estrellas principales: O, B, A, F, G, K y M, con colores que van del azul al rojo.
# Igualmente, se pueden dividir en tipos representados por números, que van del 0 al 5.
#
# Los datos presentados en este reporte equivalen a ciertas características de estrellas. Según el creador de esta base de datos: El propósito de hacer el conjunto de datos es demostrar que las estrellas siguen una determinada gráfica en el espacio celeste, específicamente llamado Diagrama de Hertzsprung-Russell o simplemente Diagrama HR, donde se traza la luminosidad contra la temperatura o la magnitud absoluta, temperatura y el color, puede revelar la clase espectral.

# %% [markdown]
# ---
# ## Sistema de clasificación de Harvard
# ---
# https://es.wikipedia.org/wiki/Clasificaci%C3%B3n_estelar
#
# ![image.png](data:image/png;base64,...)
#
# ---
# ## Diagrama HR
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## Descripción del dataset
# ---
# El dataset contiene 7 columnas y 240 filas, a continuación vemos una descripción de las variables.
#
# * Temperatura Absoluta (Grados Kelvin)
# * Luminosidad Relativa (L/Lo) -> Lo = 3.828 x 10^26 Watts (Luminosidad promedio del Sol)
# * Radio Relativo (R/Ro) -> Ro = 6.9551 x 10^8 m (Radio promedio del Sol)
# * Magnitud Absoluta (Mv)
# * Color de la Estrella
# * Clase Espectral
#   * O
#   * B
#   * A
#   * F
#   * G
#   * K
#   * M
# * Tipo de Estrella
#   * Enana roja (0)
#   * Enana café (1)
#   * Enana blanca (2)
#   * Secuencia principal (3)
#   * Supergigantes (4)
#   * Hipergigantes (5)
#
# **Magnitud absoluta ('M')**
#
# Es la magnitud aparente, 'm', que tendría un objeto si estuviera a una distancia de 10 pársecs (alrededor de 32,616 años luz) en un espacio completamente vacío sin absorción interestelar. La ventaja de la magnitud absoluta es que tiene una relación directa con las luminosidades de los astros, siendo la misma relación para cada uno de ellos, pudiendo así, al comparar las magnitudes absolutas entre dos o más astros, también comparar las luminosidades entre ellos —ya que la distancia no influye de ninguna forma.
#
#
# Y segun su tipo observamos que posee solo dos variables del tipo cualitativo, las demas son del tipo cuantitativo.
#
# ```
# Temperatura Abs       int64
# Luminosidad Rel     float64
# Radio Rel           float64
# Magnitud Abs        float64
# Color                object
# Clase Espectral      object
# Tipo de Estrella      int64
# ```
#
#
# ---
# ##Modificaciones al dataset.
# ---
# Al analizar el dataset, con la funcion OUTLIERS (tomada del tp4 realizado anteriormente), se puede observar que en la columna Color (variable cualitativa), hay datos que estan que si bien estan discriminados como distintos, se observa que son los mismos, pero estan escritos de distinta manera. Se procede a renombrarlos siguiendo la estructura del dataset original. Debajo vemos la secuencia que presenta problema.
# Se toma una copia del dataset original (stars_df), y las modificaciones realizadas quedan guardadas en el dataset stars_df_corrgido, que es el que se utiliza en el programa principal para realizar los analisis graficos y calculos.
#
# ```
#   -->  Blue White  con una frecuencia absoluta de 10
#   -->  Blue white  con una frecuencia absoluta de 4
#   -->  Blue-White  con una frecuencia absoluta de 1
#   -->  Blue-white  con una frecuencia absoluta de 26
#
#   -->  White  con una frecuencia absoluta de 7
#   -->  white  con una frecuencia absoluta de 3
#
#   -->  yellowish  con una frecuencia absoluta de 2
#   -->  Yellowish  con una frecuencia absoluta de 1
# ```
# y despues de la modificacion:
#
# ```
#   -->  Blue White  con una frecuencia absoluta de 41
#   -->  White  con una frecuencia absoluta de 10
#   -->  Yellowish  con una frecuencia absoluta de 3
#
# ```
#
#
#
#
#
# ---
# ##Valores faltantes y atipicos.
# ---
# Vemos que el dataset no presenta datos faltantes.
#
# ```
# print(stars_df_corregido.isnull().sum())
# Temperatura Abs     0
# Luminosidad Rel     0
# Radio Rel           0
# Magnitud Abs        0
# Color               0
# Clase Espectral     0
# Tipo de Estrella    0
#
# ```
#
#
#
# Y respesto a los datos atipicos, si bien se detectan en varias columnas, dado el tipo de datos que estamos utilizando y de las magnitudes que pueden tener los objetos, no es prudente eliminarlos, ya que estariamos obviando la naturaleza propia de los objetos del universo respecto a su tamaño y variedad.
#
# ###Resumen de datos dados por la funcion Describe()
# ```
#        Temperatura Abs  Luminosidad Rel    Radio Rel   Magnitud Abs   Tipo de Estrella
# count       240.000000       240.000000   240.000000    240.000000      240.000000
# mean      10497.462500    107188.361635   237.157781      4.382396      2.500000
# std        9552.425037    179432.244940   517.155763     10.532512      1.711394
# min        1939.000000         0.000080     0.008400    -11.920000      0.000000
# 25%        3344.250000         0.000865     0.102750     -6.232500      1.000000
# 50%        5776.000000         0.070500     0.762500      8.313000      2.500000
# 75%       15055.500000    198050.000000    42.750000     13.697500      4.000000
# max       40000.000000    849420.000000  1948.500000     20.060000      5.000000
#
# ```
#
# ---
# Vemos que para este dataset, no podriamos eliminar alguna columna, esto es debido que los datos volcados en el mismo representan los minimos para realizar la clasificación de estrellas.
#
# ---

# %% [markdown]
# ---
# # Funciones generales
# ---

# %%
from numpy.lib import index_tricks
from pandas._libs.lib import indices_fast
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import string
import seaborn as sns
import random
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

#https://raw.githubusercontent.com/luisbisaro/pandas.datasets/main/Stars.csv

valoresAtipicos=[]
#-----------------------------------------------------------------------------------------------------------------------
#--------------DESCRIPCION DEL DATASET ------------------------------------------------------------------------------
#-----------------------------------------------------------------------------------------------------------------------

#print(f"el dataset stars_df tiene  {stars_df.describe()} ") #hacer por dataset y con nombre de columnas
#
#-----------------------------------------------------------------------------------------------------------------------

#-----------------------------------------------------------------------------------------------------------------------
#--------------------       FUNCION PARA mostrar lo valores atipicos   OK   ----------------------------------------------
#-----------------------------------------------------------------------------------------------------------------------
def valores_atipicos(indice,descripcion1,set_a_usar1,valor_columna1,ind):

  valoresAtipicos.clear()
  #print("fun atip", indice)

  REF1= (descripcion1.iat[4,indice]) - (1.5*((descripcion1.iat[6,indice] - descripcion1.iat[4,indice])))
  REF3= (descripcion1.iat[6,indice]) + (1.5*((descripcion1.iat[6,indice] - descripcion1.iat[4,indice])))
  ver_valores=(set_a_usar1[valor_columna1[ind]])
  #ind referencia  a los nombres de las columnas del df
  #indice referencia a las filas y columnas de la df. describe()
#------------ mostrar los valores atipicos ----------------------------------------------------------

  for k in range(len(ver_valores)):  #
    if (ver_valores[k]<REF1) or (ver_valores[k]>REF3):
      valoresAtipicos.append(ver_valores[k])
  return (valoresAtipicos)

#-----------------------------------------------------------------------------------------------------------------------
#------------------FUNCION PARA DETECTAR OUTLIERS con ciclo for para ver todas las columnas -OK-------------------------
#-----------------------------------------------------------------------------------------------------------------------
#uso de la funcion
#valores=XXXX_df.describe()        #Generate descriptive statistics.
#columns = XXXX_df.columns.values  #return the column labels of the DataFrame.
#set_a_usar=XXXX_df
#outliers(valores,columns,set_a_usar)

def outliers(descripcion,columnas,set_a_usar):
  contador=0
  indiceA=0
  for i in range (len(columnas)):

    #contador=i-indiceA
    #print("dentro for ", i, indiceA)
    valor_columna=columns[0:].tolist()

    if (type(set_a_usar.iat[0,i])==str):
      indiceA +=1
      #print("dentro if ", i,"indiceA", indiceA)
      valores_unicos=np.array(np.unique(set_a_usar[valor_columna[i]], return_counts=True))
      print("la columna \033[92m",valor_columna[i],"\033[0m, contiene\033[93m", len(valores_unicos[0]),"\033[0mdatos del tipo categorico, sus valores son:")
      for j in range(len(valores_unicos[0][:])):
       #print("rango j",(len(valores_unicos[0][:])))
        #imprimo los valores
        print("  --> \033[93m",valores_unicos[0][j], "\033[0m con una frecuencia absoluta de\033[96m",valores_unicos[1][j],"\033[0m")
      print("")


    else:
      contador=i-indiceA
      valores_atipicos((contador),descripcion,set_a_usar,valor_columna,i) #  <-------------------- agrego i
      #print("else contador", contador)
      #uso la funcion para calcular los valores atipicos
      if (len(valoresAtipicos)>0):
        #si hay muestro la cantidad y sus valores, si no hay solo mensaje
        print (f"En la columna\033[1m  {valor_columna[i]} \033[0m hay \033[1m \033[92m",len(valoresAtipicos),'\033[0m',"valores atipicos y son:"'\033[92m''\033[1m',sorted(valoresAtipicos),'\033[0m') #negrita y color
      else:
        print(f"En la columna \033[1m {valor_columna[i]} \033[0m no hay valores atipicos")

#-----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# # Programa principal
# ---

# %%
#cargar el data set en un dataframe
stars_df= pd.read_csv('https://raw.githubusercontent.com/luisbisaro/pandas.datasets/main/Stars.csv')

print()
#print(stars_df.dtypes)
print()

#####################################################################################################################

#####################################################################################################################

## vemos que hay varios datos en la columna color que los toma como repetidos
## y son iguales en su sentido, los vamos a reemplazar por el correcto
#####################################################################################################################
stars_df_corregido = pd.read_csv('https://raw.githubusercontent.com/luisbisaro/pandas.datasets/main/Stars.csv')

stars_df_corregido = stars_df_corregido.replace(["Blue white","Blue-White","Blue-white"],"Blue White")
stars_df_corregido = stars_df_corregido.replace(["white"],"White")
stars_df_corregido = stars_df_corregido.replace(["yellowish"],"Yellowish")
"""
valores = stars_df_corregido.describe()
columns = stars_df_corregido.columns.values[:]
set_a_usar= stars_df_corregido
outliers(valores,columns,set_a_usar)
"""
#####################################################################################################################

##cambio de los nombres de las columnas
#####################################################################################################################
print()
print(stars_df_corregido.head(5))
print()
stars_df_corregido.columns = ['Temperatura Abs', 'Luminosidad Rel', 'Radio Rel', 'Magnitud Abs', 'Color', 'Clase Espectral','Tipo de Estrella']
print(stars_df_corregido.head(5))
print()
#print(stars_df_corregido.describe())

print(stars_df_corregido.isnull().sum())
print()
print(stars_df_corregido.dtypes)
print()

valores = stars_df_corregido.describe()
columns = stars_df_corregido.columns.values[:]
set_a_usar= stars_df_corregido
outliers(valores,columns,set_a_usar)
print()

#####################################################################################################################
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0
#
#    Temperatura Abs  Luminosidad Rel  Radio Rel  Magnitud Abs Color  \
# 0             3068         0.002400     0.1700         16.12   Red
# 1             3042         0.000500     0.1542         16.60   Red
# 2             2600         0.000300     0.1020         18.70   Red
# 3             2800         0.000200     0.1600         16.65   Red
# 4             1939         0.000138     0.1030         20.06   Red
#
#   Clase Espectral  Tipo de Estrella
# 0               M                 0
# 1               M                 0
# 2               M                 0
# ...

# %% [markdown]
# ---
# # Analisis
# ---

# %% [markdown]
# ## Univariados
#
#
# ---

# %% [markdown]
# En esta etapa, realizmos unos graficos de torta para ver la distribucion de las columas, Tipo de Estrella, Color y Clase Espectral. Vemos el porcentaje de cada catergoria respecto del total. Respecto a las variables cuantitativas, se opta por graficarlas en funcion de otra variable, esto se realizara en el apartado de Bivariados.
# Se puede ver que existe mayor cantidad de estrellas de color Red, la siguen las de color Blue y luego Blue-White
# Se puede ver que existe mayor frecuencia de Clase Espectral M, la siguen B y luego O.
# En los Tipos de estrellas, vemos que todas tienen la misma frecuencia, que es 40.

# %%
########################################### graficos de torta #############################################################
print()
print()
fig, ax = plt.subplots(1,3,facecolor = 'lightgrey',figsize=(18,15))
#-------------------------------------
valores=np.array(np.unique(stars_df_corregido['Tipo de Estrella'], return_counts=True))
valor = valores[1][:]
tipos_estrellas = ['Enana roja (0)','Enana café (1)','Enana blanca (2)','Secuencia principal (3)','Supergigantes (4)','Hipergigantes (5)']
ax[0].pie(valor, labels = tipos_estrellas, counterclock = True, autopct = '%1.1f%%')
ax[0].set_title(" Tipo de Estrella ", fontsize=15,weight="bold", verticalalignment='bottom', backgroundcolor= 'grey',loc='center')

#-------------------------------------

valores=np.array(np.unique(stars_df_corregido['Clase Espectral'], return_counts=True))
grupos = valores[0][:]
valor = valores[1][:]

ax[1].set_title("Clase Espectral", fontsize=15, weight="bold", verticalalignment='bottom', backgroundcolor= 'grey',loc='center')
ax[1].pie(valor, labels = grupos, counterclock = False, autopct = '%1.1f%%')

#-------------------------------------

valores=np.array(np.unique(stars_df_corregido['Color'], return_counts=True))
grupos = valores[0][:]
valor = valores[1][:]
wedges, texts, autotexts = ax[2].pie(valor, counterclock = False, autopct = '%1.1f%%',pctdistance=1.1,frame=False)
ax[2].legend(wedges, grupos,title="Color",loc="center right",bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size='small',color='black')
ax[2].set_title("Color", fontsize=15, weight="bold", verticalalignment='bottom', backgroundcolor= 'grey',loc='right')

#-------------------------------------
fig.tight_layout()

######################################################################################################################

# %% [markdown]
# ## Bivariados
#
#
# ---

# %% [markdown]
# En esta parte analizaremos la relacion entre dos variables, y sacar conclusiones del tipo de relacion que existe entre ellas.
#
# Se realizan cuatro graficos de barra, el eje x es el tipo de estrella (común a todas), y en el eje y se colocan las caracteristicas cuantitativas, estas son: Luminosidad, Radio, Magnitud y Temperatura. Esto lo hacemos para tener una imagen de que rango tiene la categoria entre sus valores maximos y minimos. Para el grafico de ***Temperatura Abs***, vemos que la diferencia es de aproximadamente 38.000 grados, y para la ***Magnitud Abs*** segun la definición dada anteriormente, vemos que su variación es mucho mayor, pasando de valores negativos a positivos.
# Para los gráficos de ***Radio Rel*** y ***Luminosidad Rel*** se realiza una modificación del eje y, esto es porque la medición al ser relativa, implica una división entre el valor medido y uno de referencia, y esto puede dar valores muy chicos o muy grandes. Para solucionar este problema y ver todo del rango de variación, utilizamos un eje logaritmico, a diferencia del eje lineal que utilizamos para las variables absolutas.
# En la grafíca ***Luminosidad Rel*** la variación vemos que es de 0.0008 hasta 85000, pero se puede visualizar sin problemas, algo similar sucede con la columna ***Radio Rel***.
#
# En todas las barras se visualiza también las dispersiones en cada tipo de estrella del valor graficado.

# %%
print()
sns.set_style("whitegrid")
f,(ax1, ax2,ax3,ax4) = plt.subplots(4, 1, figsize=(12,15))

#-------- 1 --------------
sns.barplot(x="Tipo de Estrella",y="Temperatura Abs",data=stars_df_corregido,ax=ax1)
ax1.set_xlabel ('  Tipo de Estrella  ')
ax1.set_ylabel("Tempreatura ABS",fontsize = 10, fontweight ='bold')
ax1.set_title (' Temperatura Abs / Tipo de Estrella ',fontsize=12,fontweight ='bold')
ax1.set_xlabel("Tipo de Estrella",fontsize = 10, fontweight ='light')
ax1.tick_params(labelsize=8)
sns.set_style("whitegrid",{'grid.linestyle': '--'})
sns.set_style("whitegrid",{'grid.color':'grey'})
#-------- 2 --------------

sns.barplot(x="Tipo de Estrella",y="Magnitud Abs",data=stars_df_corregido,ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Magnitud Abs ",fontsize = 10, fontweight ='bold')
ax2.set_title (' Magnitud Abs / Tipo de Estrella ',fontsize=12,fontweight ='bold')
ax2.set_xlabel("Tipo de Estrella",fontsize = 10, fontweight ='light')
ax2.tick_params(labelsize=8)

#-------- 3 --------------

ax3.set_yscale('log')
sns.barplot(x="Tipo de Estrella",y="Luminosidad Rel",data=stars_df_corregido,ax=ax3)
ax3.set_ylabel("Luminosidad Rel (log)",fontsize = 10, fontweight ='bold')
ax3.set_title (' Temperatura Abs / Luminosidad Rel ',fontsize=10,fontweight ='bold')
ax3.set_xlabel("Tipo de Estrella",fontsize = 10, fontweight ='light')
ax3.tick_params(labelsize=8)
#-------- 4 --------------

ax4.set_yscale('log')
sns.barplot(x="Tipo de Estrella",y="Radio Rel",data=stars_df_corregido,ax=ax4)
ax4.set_ylabel("Radio Rel (log)",fontsize = 10, fontweight ='bold')
ax4.set_xlabel("Tipo de Estrella",fontsize = 10, fontweight ='bold')
ax4.set_title (' Temperatura Abs / Radio Rel ',fontsize=12,fontweight ='light')

ax4.tick_params(labelsize=8)

#
sns.despine(bottom=False, right=True, top=True)
plt.setp(f.axes)
plt.tight_layout(h_pad=3,w_pad=3)
print()
# Out:
#   adjustable: {'box', 'datalim'}
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   anchor: (float, float) or {'C', 'SW', 'S', 'SE', 'E', 'NE', ...}
#   animated: bool
#   aspect: {'auto', 'equal'} or float
#   autoscale_on: bool
#   autoscalex_on: unknown
#   autoscaley_on: unknown
#   axes_locator: Callable[[Axes, Renderer], Bbox]
#   axisbelow: bool or 'line'
#   box_aspect: float or None
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   facecolor or fc: color
#   figure: `.Figure`
#   frame_on: bool
#   gid: str
#   in_layout: bool
#   label: object
#   mouseover: bool
#   navigate: bool
#   navigate_mode: unknown
#   path_effects: `.AbstractPathEffect`
#   picker: None or bool or float or callable
#   position: [left, bottom, width, height] or `~matplotlib.transforms.Bbox`
# ...

# %%
stars_df_corregido['Color'] = stars_df_corregido['Color'].replace(['Red','Blue','Blue White','White','yellow-white','Yellowish White','Yellowish','Whitish','Orange','Pale yellow orange','Orange-Red'], ['R','B','BW','W','YW','YsW','Ys','Ws','O','PYO','OR'])
figure = plt.figure(figsize=(12,5))
sns.barplot(x="Color",y="Tipo de Estrella",data=stars_df_corregido)
plt.show()

# %% [markdown]
# ---
# Se observa que las de color Blue-White, Whitish, Yellow-White, Yellowish y Orange-Red tienen una tendencia a ser del tipo 3, lo cual corresponde a una estrella de secuencia principal, como nuestro sol. Además, la única estrella de color Orange es considerada una de tipo Hipergigante (5), mientras que las de color Yellowish-White y Pale yellow Orange tienden a ser de tipo Enana blanca (2).
#
#
# ---

# %%
figure = plt.figure(figsize=(12,5))
sns.barplot(x="Clase Espectral",y="Tipo de Estrella",data=stars_df_corregido)
plt.show()
print(tipos_estrellas)
# Out:
# ['Enana roja (0)', 'Enana café (1)', 'Enana blanca (2)', 'Secuencia principal (3)', 'Supergigantes (4)', 'Hipergigantes (5)']

# %% [markdown]
# ---
# En este caso si son de tipo B o A es casi seguro que serán estrellas de secuencia principal (3), mientras que si son del tipo O y del G es seguro que serán Supergigantes (4) e Hipergigantes (5) respectivamente.
#
#
# ---

# %% [markdown]
# ## Relacion entre variables
#
#
# ---

# %%
features = ["Temperatura Abs","Luminosidad Rel","Radio Rel","Magnitud Abs"]
corrPearson = stars_df_corregido[features].corr(method="pearson")
corrSpearman = stars_df_corregido[features].corr(method="spearman")
plt.rcParams.update({'figure.figsize':(10,10),'figure.dpi':100})

plt.subplot(2,1,1)
sns.heatmap(corrPearson,annot=True,cmap='RdYlGn', vmin=-1, vmax=+1)
plt.title("PEARSON")
plt.show()
print()
plt.subplot(2,1,2)
sns.heatmap(corrSpearman,annot=True,cmap='RdYlGn', vmin=-1, vmax=+1)
plt.title("SPEARMAN")
plt.show()

# %% [markdown]
# ---
#
#
# Un coeficiente de correlación mide el grado en que dos variables tienden a cambiar al
# mismo tiempo. El coeficiente describe tanto la fuerza como la dirección de la relación. En los gráficos vemos que se da un color dependiendo la fuerza de la relacion entre variables, en verde las positivas y rojo las negativas, y su intensidad se representa por un gradiente de color.
#
# Los coeficientes de correlación de Pearson solo miden relaciones lineales, mientras que los coeficientes de correlación de Spearman solo miden relaciones monótonas, esto se traduce a que en ambas matrices de correlación existan valores distintos.
#
# Las correlaciones negativas quieren decir que las variables son inversamente proporcionales unas con otras, por ejemplo, si el radio aumenta disminuirá la magnitud absoluta. En cambio, las correlaciones positivas quieren decir que las variables son directamente proporcionales unas con otras, el caso de la luminosidad con el radio. Y una relacion inversamente proporcional fuerte es luminosidad y magnitud. Entre estas relaciones existen dos que son las que se grafican en la próxima sección, esta son entre magnitud y luminosidad, y magnitud y temperatura (Diagramas H-R).
#
# Vemos relaciones debiles,un ejemplo de ello son las relaciones entre radio y luminosidad, dado que su valor es casi cero, debemos concluir que no hay relacion entre ellas.
#
#
#
# ---

# %% [markdown]
# ## Diagrama H-R - Conclusiones del analisis
# ---

# %% [markdown]
# Tanto la temperatura como la luminosidad de la estrella se relacionan mejor con su magnitud absoluta, para un mejor estudio se verán dos gráficos de dispersión con una barra de color que hace alusión al Diagrama de Hertzsprung-Russell.
#
# El diagrama H-R se utiliza para diferenciar tipos de estrellas y para estudiar la evolución estelar. Un examen del diagrama muestra que las estrellas tienden a encontrarse agrupadas en regiones específicas del mismo. La predominante es la diagonal que va de la región superior izquierda (caliente y brillante) a la región inferior derecha (fría y menos brillante) y se denomina secuencia principal. En este grupo se encuentran las estrellas que extraen su energía de las reacciones termonucleares de fusión del hidrógeno en helio. En la esquina inferior izquierda se encuentran las enanas blancas, y por encima de la secuencia principal se encuentran las gigantes rojas y las supergigantes.
#
# Observamos una tendecia de las estrellas de Tipo 2 a posicionarse en la parte superior izquierda de la gráfica, mientras que las de Tipo 4 y Tipo 5 se alinean en la parte inferior. Se presenta tambien lo que se conoce como Secuencia Principal que son las estrellas del Tipo 3, formando una “cola de ratón”. Para entender este comportamiento debemos definir la Magnitud Absoluta, que es nuestro eje y. Este valor indica qué tan brillante es un objeto para un observador a cierta distancia, es decir está en funcion de la luminosidad. Cabe recalcar que mientras mayor es el valor de la Magnitud Absoluta menos brillante es una estrella.
#
# De estas dos gráficas podemos concluir que las estrellas de Tipo 5, es decir Hipergigantes, presentan un radio relativo mayor a 500 y una luminosidad (Magnitud Absoluta) alta, lo cuál podemos inferir que se debe a su gran tamaño mas no a su temperatura, ya que en el segundo gráfico observamos que las estrellas hipergigantes poseen temperaturas desde muy bajas hasta muy altas. Por su parte, las estrellas de Tipo 2 o Enanas Blancas a pesar de tener temperaturas relativamente altas, es su menor tamaño lo que provoca que irradien menos luz.
#
# * Las estrella de Tipo 0 y Tipo 1, es decir enanas rojas y marrones están caracterizadas por pertenecer al tipo espectral M en su totalidad, además su radio, temperatura y luminosidad presenta valores muy bajos. En el Diagrama H-R, todas las estrellas de estos tipos se encuentran en el cuadrante superior izquierdo.
# * Las estrellas de Tipo 2 o enanas blancas, estan ubicadas en los cuadrantes adyacentes a las estrellas de tipo 0 y 1 en el diagrama H-R, esto se debe a su tamaño, lo que hace que irradien muy poca luz, a pesar de su temperatura, la cual supera los 5000 K, lo que provoca que tomen colores blancos y amarillentos.
# * Las estrellas ubicadas en la secuencia principal serán las de Tipo 3, estas estrellas mantienen una relación predecible entre luminosidad y temperatura (la más brillante es la más caliente). Su magnitud absluta varía entre -5 y 7.
# * Finalmente las estrellas de Tipo 4 y Tipo 5, es decir Supergigantes e Hipergigantes poseen una magnitud absoluta que va desde -5 en adelante, es decir irradian mucha luz, lo cuál se debe a su tamaño, lo cuál es mas notorio en las Hipergigantes, cabe recalcar que cualquier estrella cuyo radi relativo sea mayor a 500 ya se clasifica cómo Hipergigante.
# Cómo observación final, es necesario recalcar que temperatura no equivale a luminocidad, en el caso de las Hipergigantes, existen aquellas que presentan temperaturas bajas, pero debido a su tamaño irradian gran cantidad de energía lumínica.

# %%
print()

stars_df_corregido['Tipo de Estrella'] = stars_df_corregido['Tipo de Estrella'].replace([0,1,2,3,4,5],['Enana roja','Enana café','Enana blanca','Secuencia principal','Supergigantes','Hipergigantes'])

plt.rcParams.update({'figure.figsize':(16,7),'figure.dpi':100})
plt.subplot(1, 2, 1)
fig = sns.scatterplot(data=stars_df_corregido, x='Luminosidad Rel', y='Magnitud Abs',  hue='Tipo de Estrella')
plt.title('Diagrama de Hertzsprung-Russell (L vs Mv)')
plt.xlabel('Luminosidad (L/Lo)')
plt.ylabel('Magnitud Absoluta (Mv)')

plt.subplot(1, 2, 2)
fig = sns.scatterplot(data=stars_df_corregido, x='Temperatura Abs', y='Magnitud Abs',  hue='Tipo de Estrella')
plt.title('Diagrama de Hertzsprung-Russell (T vs Mv)')
plt.xlabel('Temperatura (K)')
plt.ylabel('Magnitud Absoluta (Mv)')

plt.show()

# %% [markdown]
# ## Graficos 3D
#
#
# ---

# %% [markdown]
# Mediante gráficos 3D se verá la relación entre:
#
# * Temperatura, Luminosidad y Magnitud Absoluta
# * Temperatura, Luminosidad y Radio
# * Temperatura, Radio y Magnitud Absoluta
# * Luminosidad, Radio y Magnitud Absoluta
#
# Vemos que en cada gráfico podemos ver como hacer grupos de estrellas con caracteristicas similares (clusters).
# Utilizamos https://plotly.com/python/3d-scatter-plots/

# %%
stars_df_corregido['Tipo de Estrella'] = stars_df_corregido['Tipo de Estrella'].replace([0,1,2,3,4,5],['Enana roja','Enana café','Enana blanca','Secuencia principal','Supergigantes','Hipergigantes'])
df = stars_df_corregido
fig = px.scatter_3d(df, x='Temperatura Abs', y='Luminosidad Rel', z='Magnitud Abs', color='Tipo de Estrella')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---

# %%
stars_df_corregido['Tipo de Estrella'] = stars_df_corregido['Tipo de Estrella'].replace([0,1,2,3,4,5],['Enana roja','Enana café','Enana blanca','Secuencia principal','Supergigantes','Hipergigantes'])
df = stars_df_corregido

fig = px.scatter_3d(df, x='Temperatura Abs', y='Luminosidad Rel', z='Radio Rel', color='Tipo de Estrella')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---

# %%
stars_df_corregido['Tipo de Estrella'] = stars_df_corregido['Tipo de Estrella'].replace([0,1,2,3,4,5],['Enana roja','Enana café','Enana blanca','Secuencia principal','Supergigantes','Hipergigantes'])
df = stars_df_corregido
fig = px.scatter_3d(df, x='Temperatura Abs', y='Radio Rel', z='Magnitud Abs', color='Tipo de Estrella')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---

# %%
stars_df_corregido['Tipo de Estrella'] = stars_df_corregido['Tipo de Estrella'].replace([0,1,2,3,4,5],['Enana roja','Enana café','Enana blanca','Secuencia principal','Supergigantes','Hipergigantes'])
df = stars_df_corregido
fig = px.scatter_3d(df, x='Luminosidad Rel', y='Radio Rel', z='Magnitud Abs', color='Tipo de Estrella')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Funcion corregida y probada TP4
# ---

# %%
### Funcion outliers TP4 funcionando OK, para cualquier dataframe, probada en titanic. 25/08

titanic_df= pd.read_csv('https://raw.githubusercontent.com/luisbisaro/pandas.datasets/main/titanic.csv')

titanic_df.Embarked.fillna('N/D',inplace=True) #reemplazo los valores NaN con n
titanic_df.Cabin.fillna('N/D',inplace=True) #reemplazo los valores NaN con n
edad_media = round(np.mean(titanic_df['Age'], axis=0),2)
titanic_df.Age.fillna(edad_media,inplace=True)

valores=titanic_df.describe()
columns = titanic_df.columns.values[:]  #  cambio 25/08
set_a_usar=titanic_df
outliers(valores,columns,set_a_usar)
